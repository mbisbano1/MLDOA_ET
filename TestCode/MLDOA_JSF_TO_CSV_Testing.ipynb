# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
test_path = "D:\OneDrive\OneDrive - University of Massachusetts Dartmouth\ECE457_Senior_Design_ECE5\CSV_Files\\0001_1404.002_jsf_repackingTest_port.csv"
df_test=pd.read_csv(test_path)

# %%
df_test
# Out:
#          PingNum  SampleNum  PortStbd  SampleTimeDelay       I1       Q1  \
# 0          87443          5         0         0.000061   0.0000   0.0000
# 1          87443          6         0         0.000077   0.0000   0.0000
# 2          87443          7         0         0.000092   0.0000   0.0000
# 3          87443          8         0         0.000108   0.0000   0.0000
# 4          87443          9         0         0.000123   0.0000   0.0000
# ...          ...        ...       ...              ...      ...      ...
# 5504452    88723       4297         0         0.065982 -28.2500  24.0000
# 5504453    88723       4298         0         0.065998 -70.8750  26.7500
# 5504454    88723       4299         0         0.066013 -42.5625  15.3750
# 5504455    88723       4300         0         0.066028  35.9375 -15.7500
# 5504456    88723       4301         0         0.066044  68.6250 -22.3125
#
#               I2       Q2       I3       Q3  ...      I10      Q10      Roll  \
# ...

# %%
plt.plot(df_test["DOA"])

# %%
doas = df_test["DOA"]
doas
# Out:
# 0         -55.809999
# 1         -55.809999
# 2         -55.809999
# 3         -55.809999
# 4         -55.809999
#              ...
# 5504452   -82.134998
# 5504453   -80.939998
# 5504454   -80.624998
# 5504455   -80.924998
# 5504456   -79.104998
# Name: DOA, Length: 5504457, dtype: float64
