# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# import the csv as a pandas dataframe
data= pd.read_csv('Training_Port1.csv')

# %%
# display the dataframe
data
# Out:
#          Ping#  Sample#  Port/Stbd  SampleTimeDelay       I1       Q1  \
# 0            7      5.0          0         0.000061   0.0000   0.0000
# 1            7      6.0          0         0.000077   0.0000   0.0000
# 2            7      7.0          0         0.000092   0.0000   0.0000
# 3            7      8.0          0         0.000108   0.0000   0.0000
# 4            7      9.0          0         0.000123   0.0000   0.0000
# ...        ...      ...        ...              ...      ...      ...
# 5504453   1287   4298.0          0         0.065998 -70.8750  26.7500
# 5504454   1287   4299.0          0         0.066013 -42.5625  15.3750
# 5504455   1287   4300.0          0         0.066028  35.9375 -15.7500
# 5504456   1287   4301.0          0         0.066044  68.6250 -22.3125
# 5504457   1288      NaN          0         0.000000   0.0000   0.0000
#
#               I2       Q2       I3       Q3  ...      I10      Q10      Roll  \
# 0         0.0000   0.0000   0.0000   0.0000  ...   0.0000   0.0000  0.488892
# 1         0.0000   0.0000   0.0000   0.0000  ...   0.0000   0.0000  0.488892
# 2         0.0000   0.0000   0.0000   0.0000  ...   0.0000   0.0000  0.488892
# 3         0.0000   0.0000   0.0000   0.0000  ...   0.0000   0.0000  0.488892
# 4         0.0000   0.0000   0.0000   0.0000  ...   0.0000   0.0000  0.488892
# ...          ...      ...      ...      ...  ...      ...      ...       ...
# 5504453 -85.9375 -40.1250   7.2500  78.1250  ... -55.4375  41.7500  1.016235
# 5504454 -26.6875  19.9375  14.5625  48.1875  ...  36.8125  28.3125  1.016235
# 5504455  36.2500  44.2500  13.1875 -39.5000  ...  47.1250  61.1875  1.016235
# 5504456  16.0000  38.6875  20.3125 -71.5000  ...   0.6250  68.0625  1.016235
# 5504457   0.0000   0.0000   0.0000   0.0000  ...   0.0000   0.0000  0.000000
#
#                 C        DOA      TWTT  Amplitude  AngleUncertainty  \
# 0        1492.040 -55.809999  0.000061          0                 0
# 1        1492.040 -55.809999  0.000077          0                 0
# 2        1492.040 -55.809999  0.000092          0                 0
# 3        1492.040 -55.809999  0.000108          0                 0
# 4        1492.040 -55.809999  0.000123          0                 0
# ...           ...        ...       ...        ...               ...
# 5504453  1491.949 -80.939998  0.065998         84                97
# 5504454  1491.949 -80.624998  0.066013         96                32
# 5504455  1491.949 -80.924998  0.066028         90                48
# 5504456  1491.949 -79.104998  0.066044         84               113
# 5504457     0.000   0.000000  0.000000          0                 0
#
#           SampleRate      Range
# 0        65108.40625   0.045832
# 1        65108.40625   0.057291
# 2        65108.40625   0.068749
# 3        65108.40625   0.080207
# 4        65108.40625   0.091665
# ...              ...        ...
# 5504453  65108.40625  49.232546
# 5504454  65108.40625  49.244004
# 5504455  65108.40625  49.255461
# 5504456  65108.40625  49.266919
# 5504457      0.00000   0.000000
#
# [5504458 rows x 32 columns]

# %%
# extract the data
doa=data.DOA
sample_num=data.iloc[:,1] # Gets Sample# column
i1=data.I1
i2=data.I2
i3=data.I3
i4=data.I4
i5=data.I5
i6=data.I6
i7=data.I7
i8=data.I8
i9=data.I9
i10=data.I10
q1=data.Q1
q2=data.Q2
q3=data.Q3
q4=data.Q4
q5=data.Q5
q6=data.Q6
q7=data.Q7
q8=data.Q8
q9=data.Q9
q10=data.Q10

# %%
sample_num
# Out:
# 0             5.0
# 1             6.0
# 2             7.0
# 3             8.0
# 4             9.0
#             ...
# 5504453    4298.0
# 5504454    4299.0
# 5504455    4300.0
# 5504456    4301.0
# 5504457       NaN
# Name: Sample#, Length: 5504458, dtype: float64

# %%
#plot i1 and q1 versus DOA (1st 10000 pts)
#this shows the releationship between I and Q data and DOA
plt.plot(i1[1:10000],doa[1:10000],'o')
plt.plot(q1[1:10000],doa[1:10000], 'o')
plt.title('I1 and Q1 VS DOA')
plt.xlabel('I1 and Q1 data -PORT TRAINING DATA')
plt.ylabel('DOA (degrees)')
plt.legend(['I1','Q1'])
plt.show()

# %%
#plot i2 and q2 versus DOA (1st 10000 pts)
plt.plot(i2[1:10000],doa[1:10000],'o')
plt.plot(q2[1:10000],doa[1:10000], 'o')
plt.title('I2 and Q2 VS DOA')
plt.xlabel('I2 and Q2 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I2','Q2'])
plt.show()

# %%
#plot i3 and q3 versus DOA (1st 10000 pts)
plt.plot(i3[1:10000],doa[1:10000],'o')
plt.plot(q3[1:10000],doa[1:10000], 'o')
plt.title('I3 and Q3 VS DOA')
plt.xlabel('I3 and Q3 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I3','Q3'])
plt.show()

# %%
#plot i4 and q4 versus DOA (1st 10000 pts)
plt.plot(i4[1:10000],doa[1:10000],'o')
plt.plot(q4[1:10000],doa[1:10000], 'o')
plt.title('I4 and Q4 VS DOA')
plt.xlabel('I4 and Q4 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I4','Q4'])
plt.show()

# %%
#plot i5 and q5 versus DOA (1st 10000 pts)
plt.plot(i5[1:10000],doa[1:10000],'o')
plt.plot(q5[1:10000],doa[1:10000], 'o')
plt.title('I5 and Q5 VS DOA')
plt.xlabel('I5 and Q5 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I5','Q5'])
plt.show()

# %%
#plot i4 and q4 versus DOA (1st 10000 pts)
plt.plot(i4[1:100000],doa[1:100000],'o')
plt.plot(q4[1:100000],doa[1:100000], 'o')
plt.title('I4 and Q4 VS DOA')
plt.xlabel('I4 and Q4 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I4','Q4'])
plt.show()

# %%
# Look at the relationship between the I1 and I2 Data
plt.plot(i1[1:10000],doa[1:10000],'o')
plt.plot(i2[1:10000],doa[1:10000], 'o')
plt.title('I1 and I2 VS DOA')
plt.xlabel('I1 and I2 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I1','I2'])
plt.show()

# %%
#show the realationship between DOA and concurrent samples (1st 10,000 pts)
plt.plot(sample_num[0:4297],doa[0:4297],'o')
plt.title('sample number VS DOA')
plt.xlabel('sample number')
plt.ylabel('DOA (degrees)')
plt.show()
