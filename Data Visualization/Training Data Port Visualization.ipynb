# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# import the csv as a pandas dataframe
data=pd.read_csv(r'C:\Users\Daniel\OneDrive - University of Massachusetts Dartmouth\ECE457_Senior_Design_ECE5\CSV_Files\PortTraining_1404_002_FINAL_startingAt24.csv')

# %%
# display the dataframe
data
# Out:
#          PingNum  SampleNum  PortStbd  SampleTimeDelay       I1       Q1  \
# 0          87443         24         0         0.000353   0.0000   0.0000
# 1          87443         25         0         0.000369   0.0000   0.1250
# 2          87443         26         0         0.000384   0.1250   0.0000
# 3          87443         27         0         0.000399  -0.1250  -0.1250
# 4          87443         28         0         0.000415  -0.1250   0.2500
# ...          ...        ...       ...              ...      ...      ...
# 5480113    88723       4297         0         0.065982 -28.2500  24.0000
# 5480114    88723       4298         0         0.065998 -70.8750  26.7500
# 5480115    88723       4299         0         0.066013 -42.5625  15.3750
# 5480116    88723       4300         0         0.066028  35.9375 -15.7500
# 5480117    88723       4301         0         0.066044  68.6250 -22.3125
#
#               I2       Q2       I3       Q3  ...      I10      Q10      Roll  \
# ...

# %%
# extract the data
doa=data.DOA
sample_num=data.iloc[:,1] # Gets Sample# column
i1=data.I1
i2=data.I2
i3=data.I3
i4=data.I4
i5=data.I5
i6=data.I6
i7=data.I7
i8=data.I8
i9=data.I9
i10=data.I10
q1=data.Q1
q2=data.Q2
q3=data.Q3
q4=data.Q4
q5=data.Q5
q6=data.Q6
q7=data.Q7
q8=data.Q8
q9=data.Q9
q10=data.Q10
amp=data.Amplitude

# %%
sample_num
# Out:
# 0            24
# 1            25
# 2            26
# 3            27
# 4            28
#            ...
# 5480113    4297
# 5480114    4298
# 5480115    4299
# 5480116    4300
# 5480117    4301
# Name: SampleNum, Length: 5480118, dtype: int64

# %%
#plot i1 and q1 versus DOA (1st 10000 pts)
#this shows the releationship between I and Q data and DOA
plt.plot(i1[1:10000],doa[1:10000],'o')
plt.plot(q1[1:10000],doa[1:10000], 'o')
plt.title('I1 and Q1 VS DOA')
plt.xlabel('I1 and Q1 data -PORT TRAINING DATA')
plt.ylabel('DOA (degrees)')
plt.legend(['I1','Q1'])
plt.show()

# %%
#plot i2 and q2 versus DOA (1st 10000 pts)
plt.plot(i2[1:10000],doa[1:10000],'o')
plt.plot(q2[1:10000],doa[1:10000], 'o')
plt.title('I2 and Q2 VS DOA')
plt.xlabel('I2 and Q2 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I2','Q2'])
plt.show()

# %%
#plot i3 and q3 versus DOA (1st 10000 pts)
plt.plot(i3[1:10000],doa[1:10000],'o')
plt.plot(q3[1:10000],doa[1:10000], 'o')
plt.title('I3 and Q3 VS DOA')
plt.xlabel('I3 and Q3 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I3','Q3'])
plt.show()

# %%
#plot i4 and q4 versus DOA (1st 10000 pts)
plt.plot(i4[1:10000],doa[1:10000],'o')
plt.plot(q4[1:10000],doa[1:10000], 'o')
plt.title('I4 and Q4 VS DOA')
plt.xlabel('I4 and Q4 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I4','Q4'])
plt.show()

# %%
#plot i5 and q5 versus DOA (1st 10000 pts)
plt.plot(i5[1:10000],doa[1:10000],'o')
plt.plot(q5[1:10000],doa[1:10000], 'o')
plt.title('I5 and Q5 VS DOA')
plt.xlabel('I5 and Q5 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I5','Q5'])
plt.show()

# %%
#plot i4 and q4 versus DOA (1st 10000 pts)
plt.plot(i4[1:100000],doa[1:100000],'o')
plt.plot(q4[1:100000],doa[1:100000], 'o')
plt.title('I4 and Q4 VS DOA')
plt.xlabel('I4 and Q4 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I4','Q4'])
plt.show()

# %%
# Look at the relationship between the I1 and I2 Data
plt.plot(i1[1:10000],doa[1:10000],'o')
plt.plot(i2[1:10000],doa[1:10000], 'o')
plt.title('I1 and I2 VS DOA')
plt.xlabel('I1 and I2 data')
plt.ylabel('DOA (degrees)')
plt.legend(['I1','I2'])
plt.show()

# %%
#show the realationship between DOA and concurrent samples (1st 10,000 pts)
plt.plot(sample_num[0:4297],doa[0:4297],'o')
plt.title('sample number VS DOA')
plt.xlabel('sample number')
plt.ylabel('DOA (degrees)')
plt.show()

# %%
#show the realationship between DOA and amplitude (1st 10,000 pts)
plt.plot(amp[0:4297],doa[0:4297],'o')
plt.title('sample number VS DOA')
plt.xlabel('sample number')
plt.ylabel('DOA (degrees)')
plt.show()
